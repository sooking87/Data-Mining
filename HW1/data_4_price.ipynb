# %% [markdown]
# attr_name = ['no_of_adults', 'no_of_children', 'no_of_weekend_nights',
#        'no_of_week_nights', 'type_of_meal_plan', 'required_car_parking_space',
#        'room_type_reserved', 'lead_time', 'arrival_year', 'arrival_month',
#        'arrival_date', 'market_segment_type', 'repeated_guest',
#        'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled',
#        'avg_price_per_room', 'no_of_special_requests', 'booking_status']

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

data = pd.read_csv('num_booking_status.csv')
print(max(list(data['avg_price_per_room'])))
# Out:
# 375.5

# %%
plt.figure(figsize=(15, 2))
plt.scatter(data["avg_price_per_room"], data["type_of_meal_plan"], alpha=0.1)
plt.title(data["avg_price_per_room"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\STUDY\5학기\Data-Mining\data_4_price.ipynb Cell 5 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/STUDY/5%ED%95%99%EA%B8%B0/Data-Mining/data_4_price.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> plt.figure(figsize=(15, 2))
#       <a href='vscode-notebook-cell:/c%3A/STUDY/5%ED%95%99%EA%B8%B0/Data-Mining/data_4_price.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> plt.scatter(data["avg_price_per_room"], data["type_of_meal_plan"], alpha=0.1)
# ----> <a href='vscode-notebook-cell:/c%3A/STUDY/5%ED%95%99%EA%B8%B0/Data-Mining/data_4_price.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> plt.title(data["avg_price_per_room"])
#       <a href='vscode-notebook-cell:/c%3A/STUDY/5%ED%95%99%EA%B8%B0/Data-Mining/data_4_price.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> plt.show()
#
# ...

# %%
plt.figure(figsize=(15, 5))
plt.scatter(data["avg_price_per_room"], data["room_type_reserved"], alpha=0.1)
plt.title(data["avg_price_per_room"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\STUDY\5학기\Data-Mining\data_4_price.ipynb Cell 6 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/STUDY/5%ED%95%99%EA%B8%B0/Data-Mining/data_4_price.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> plt.figure(figsize=(15, 5))
#       <a href='vscode-notebook-cell:/c%3A/STUDY/5%ED%95%99%EA%B8%B0/Data-Mining/data_4_price.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> plt.scatter(data["avg_price_per_room"], data["room_type_reserved"], alpha=0.1)
# ----> <a href='vscode-notebook-cell:/c%3A/STUDY/5%ED%95%99%EA%B8%B0/Data-Mining/data_4_price.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> plt.title(data["avg_price_per_room"])
#       <a href='vscode-notebook-cell:/c%3A/STUDY/5%ED%95%99%EA%B8%B0/Data-Mining/data_4_price.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a> plt.show()
#
# ...

# %%
plt.figure(figsize=(15, 5))
plt.scatter(data["avg_price_per_room"], data["no_of_children"], alpha=0.1)
plt.title(data["avg_price_per_room"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\STUDY\5학기\Data-Mining\data_4_price.ipynb Cell 5 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/STUDY/5%ED%95%99%EA%B8%B0/Data-Mining/data_4_price.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> plt.figure(figsize=(15, 5))
#       <a href='vscode-notebook-cell:/c%3A/STUDY/5%ED%95%99%EA%B8%B0/Data-Mining/data_4_price.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> plt.scatter(data["avg_price_per_room"], data["no_of_children"], alpha=0.1)
# ----> <a href='vscode-notebook-cell:/c%3A/STUDY/5%ED%95%99%EA%B8%B0/Data-Mining/data_4_price.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a> plt.title(data["avg_price_per_room"])
#       <a href='vscode-notebook-cell:/c%3A/STUDY/5%ED%95%99%EA%B8%B0/Data-Mining/data_4_price.ipynb#X12sZmlsZQ%3D%3D?line=3'>4</a> plt.show()
#
# ...

# %%
plt.figure(figsize=(15, 5))
plt.scatter(data["avg_price_per_room"], data["repeated_guest"], alpha=0.1)
plt.title(data["avg_price_per_room"])
plt.show()

# %%
plt.figure(figsize=(15, 2))
plt.scatter(data["avg_price_per_room"], data["booking_status"], alpha=0.1)
plt.title(data["avg_price_per_room"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\STUDY\5학기\Data-Mining\data_4_price.ipynb Cell 3 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/STUDY/5%ED%95%99%EA%B8%B0/Data-Mining/data_4_price.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> plt.figure(figsize=(15, 2))
#       <a href='vscode-notebook-cell:/c%3A/STUDY/5%ED%95%99%EA%B8%B0/Data-Mining/data_4_price.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> plt.scatter(data["avg_price_per_room"], data["booking_status"], alpha=0.1)
# ----> <a href='vscode-notebook-cell:/c%3A/STUDY/5%ED%95%99%EA%B8%B0/Data-Mining/data_4_price.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> plt.title(data["avg_price_per_room"])
#       <a href='vscode-notebook-cell:/c%3A/STUDY/5%ED%95%99%EA%B8%B0/Data-Mining/data_4_price.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> plt.show()
#
# ...
