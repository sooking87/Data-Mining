# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold, cross_val_score
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv('real_real_final_train.csv')
feature_names = ['no_of_adults',
                 'type_of_meal_plan', 'required_car_parking_space', 'room_type_reserved',
                 'lead_time', 'market_segment_type',
                 'avg_price_per_room', 'no_of_special_requests',
                 'nights', 'lead_x_nights']

# %%
sb.scatterplot(x=df['no_of_adults'],y=df['no_of_adults'], hue=df['booking_status'])
# Out:
# <AxesSubplot:xlabel='no_of_adults', ylabel='no_of_adults'>

# %%
sb.scatterplot(x=df['type_of_meal_plan'],y=df['type_of_meal_plan'], hue=df['booking_status'])
# Out:
# <AxesSubplot:xlabel='type_of_meal_plan', ylabel='type_of_meal_plan'>

# %%
sb.scatterplot(x=df['required_car_parking_space'],y=df['required_car_parking_space'], hue=df['booking_status'])
# Out:
# <AxesSubplot:xlabel='required_car_parking_space', ylabel='required_car_parking_space'>

# %%
sb.scatterplot(x=df['room_type_reserved'],y=df['room_type_reserved'], hue=df['booking_status'])
# Out:
# <AxesSubplot:xlabel='room_type_reserved', ylabel='room_type_reserved'>

# %%
sb.scatterplot(x=df['lead_time'],y=df['lead_time'], hue=df['booking_status'])
# Out:
# <AxesSubplot:xlabel='lead_time', ylabel='lead_time'>

# %%
sb.scatterplot(x=df['avg_price_per_room'],y=df['avg_price_per_room'], hue=df['booking_status'])
# Out:
# <AxesSubplot:xlabel='avg_price_per_room', ylabel='avg_price_per_room'>
