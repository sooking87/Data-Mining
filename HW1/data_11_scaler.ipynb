# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import MaxAbsScaler
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold, cross_val_score
import matplotlib.pyplot as plt
import seaborn as sb
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('real_real_final_train.csv')
test = pd.read_csv('real_real_final_test.csv')

train.booking_status.hist()
# Out:
# <AxesSubplot:>

# %%
train.family.hist()
# Out:
# <AxesSubplot:>

# %%
train.no_of_weekend_nights.hist()
# Out:
# <AxesSubplot:>

# %%
train.no_of_week_nights.hist()
# Out:
# <AxesSubplot:>

# %%
train.lead_time.hist()
# Out:
# <AxesSubplot:>

# %%
train.no_of_previous_cancellations.hist()
# Out:
# <AxesSubplot:>

# %%
train.no_of_previous_bookings_not_canceled.hist()
# Out:
# <AxesSubplot:>

# %%
train.avg_price_per_room.hist()
# Out:
# <AxesSubplot:>

# %%
train.no_of_special_requests.hist()
# Out:
# <AxesSubplot:>

# %%
train.lead_nights.hist()
# Out:
# <AxesSubplot:>

# %%
train.nights.hist()
# Out:
# <AxesSubplot:>

# %%
train.lead_weekend_nights.hist()
# Out:
# <AxesSubplot:>

# %%
train.lead_car.hist()
# Out:
# <AxesSubplot:>

# %%
train.lead_room.hist()
# Out:
# <AxesSubplot:>

# %%
train.lead_market.hist()
# Out:
# <AxesSubplot:>

# %%
train.lead_price.hist()
# Out:
# <AxesSubplot:>

# %%
train.price_adults.hist()
# Out:
# <AxesSubplot:>

# %%
train.price_room.hist()
# Out:
# <AxesSubplot:>

# %%
train.requests_room.hist()
# Out:
# <AxesSubplot:>

# %%
data = pd.read_csv('real_real_final_train.csv')
data.keys()
# Out:
# Index(['no_of_weekend_nights', 'no_of_week_nights', 'type_of_meal_plan',
#        'required_car_parking_space', 'room_type_reserved', 'lead_time',
#        'market_segment_type', 'repeated_guest', 'no_of_previous_cancellations',
#        'no_of_previous_bookings_not_canceled', 'avg_price_per_room',
#        'no_of_special_requests', 'booking_status', 'nights', 'lead_nights',
#        'lead_weekend_nights', 'lead_car', 'lead_room', 'lead_market',
#        'lead_price', 'price_adults', 'price_room', 'requests_room', 'family'],
#       dtype='object')

# %%
data = pd.read_csv('real_real_final_train.csv')

sb.pairplot( data=data, vars=(
       'lead_weekend_nights', 'lead_car', 'lead_room', 'lead_market',
       'lead_price', 'price_adults', 'price_room'), plot_kws=dict(alpha=0.1), hue='booking_status' )
