# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

'''
attr_name = ['no_of_adults', 'no_of_children', 'no_of_weekend_nights',
       'no_of_week_nights', 'type_of_meal_plan', 'required_car_parking_space',
       'room_type_reserved', 'lead_time', 'arrival_year', 'arrival_month',
       'arrival_date', 'market_segment_type', 'repeated_guest',
       'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled',
       'avg_price_per_room', 'no_of_special_requests', 'booking_status']
'''

train = pd.read_csv('num_booking_status.csv')

feature_names = ['no_of_adults', 'no_of_children', 'required_car_parking_space',
       'lead_time', 'repeated_guest', 'no_of_previous_bookings_not_canceled']
X = train[feature_names]
temp = X[X['no_of_previous_bookings_not_canceled'] == 0]['no_of_previous_bookings_not_canceled']
print(temp)
# no_of_previous_bookings_not_canceled -> 대부분 이전에 not cancel 한 적이 없다.
train
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 25387    0
# 25388    0
# 25389    0
# 25390    0
# 25391    0
# Name: no_of_previous_bookings_not_canceled, Length: 24825, dtype: int64
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0       INN29581             2               0                     1
# 1       INN06326             2               0                     1
# 2       INN33900             2               0                     1
# 3       INN00721             2               0                     2
# 4       INN22121             2               1                     0
# ...          ...           ...             ...                   ...
# 25387   INN16851             2               0                     2
# 25388   INN06266             1               0                     0
# 25389   INN11285             2               0                     0
# ...
